# %% [markdown]
# # A Comprehension of Intelligent Document Processing
#
# Intelligent Document Processing (IDP) is an advanced automation technology that transforms the way businesses handle documents. By leveraging artificial intelligence (AI), IDP systems can automatically read, understand, and process vast quantities of documents, extracting crucial data and feeding it into various business workflows. This technology is a significant leap from traditional Optical Character Recognition (OCR) as it not only digitizes text but also comprehends the context and structure of the information within documents.
#
# At its core, IDP is designed to tackle the challenge of processing unstructured and semi-structured data, which make up a large portion of business documents such as invoices, contracts, emails, and forms. By automating the extraction and interpretation of this data, IDP significantly reduces the need for manual data entry, leading to increased efficiency, higher accuracy, and substantial cost savings.
#
# <br><br>
#
# ---
# <br><br>
#
# ### The Inner Workings of Intelligent Document Processing
#
# The power of IDP lies in its sophisticated multi-step process that intelligently handles documents from ingestion to data delivery. This process typically involves several key stages:
#
# **1. Document Ingestion:** The first step involves importing documents from various sources and in multiple formats, including scanned paper documents, PDFs, Word files, and images.
#
# **2. Pre-processing:** To enhance the quality of the input, documents undergo a pre-processing stage. This includes techniques like noise reduction, image enhancement, and deskewing to improve the accuracy of subsequent data extraction.
#
# **3. Document Classification:** Using machine learning algorithms, the IDP system automatically categorizes documents based on their layout and content. This allows the system to differentiate between an invoice, a purchase order, or a legal contract, for instance.
#
# **4. Data Extraction:** This is the core function of IDP. Advanced AI technologies, including Natural Language Processing (NLP) and computer vision, are employed to identify and extract relevant data fields. For example, from an invoice, it can pull out the invoice number, date, vendor name, and line-item details.
#
# **5. Data Validation:** The extracted data is then validated against predefined rules and existing databases to ensure accuracy and consistency. Any exceptions or discrepancies can be flagged for human review in a "human-in-the-loop" process, which also helps to train and improve the AI model over time.
#
# **6. Integration:** Finally, the structured and validated data is seamlessly integrated into downstream business systems such as Enterprise Resource Planning (ERP), Customer Relationship Management (CRM), or other databases, making the information readily available for further processing and analysis.
#
#
# From **finance departments** automating invoice processing and expense management to **healthcare organizations** streamlining patient record management and claims processing, IDP is proving to be a game-changer. Even  **human resources** can expedite resume screening and employee onboarding. As the technology continues to evolve, its applications are expected to expand even further, solidifying its role as a cornerstone of modern digital transformation.

# %% [markdown]
# # Our Approach

# %% [markdown]
# ![21 pros-ocr.drawio.png](data:image/png;base64,...)

# %% [markdown]
# # SROIEv2: The Receipts Dataset

# %% [markdown]
# ## Getting the data

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("urbikn/sroie-datasetv2")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/ganeshkanagavel/.cache/kagglehub/datasets/urbikn/sroie-datasetv2/versions/4

# %%
! cat /Users/ganeshkanagavel/.cache/kagglehub/datasets/urbikn/sroie-datasetv2/versions/4/SROIE2019/test/entities/X00016469670.txt
# Out:
# {
#     "company": "OJC MARKETING SDN BHD",
#     "date": "15/01/2019",
#     "address": "NO 2 & 4, JALAN BAYU 4, BANDAR SERI ALAM, B1750 MASAI, JOHOR",
#     "total": "193.00"
# }

# %% [markdown]
# Since these are single-paged images already, we don't need to convert them

# %% [markdown]
# ## Understanding the data
#
#
# The downloaded dataset contains two major folders:
# 1. **train**: This folder contains the training data.
# 2. **test**: This folder contains the test data.
#
# Each of these folders contains the following subfolders:
# 1. **img**: This folder containing the images of the receipts.
# 2. **box**: This folder containing the bounding box information of the text in the images and the text inside the bounding boxes. The file is a text file with the same name as the image file but with a .txt extension. The format of the file is as follows:
#     ```
#     x1, y1, x2, y2, x3, y3, x4, y4, text
#     ```
#     where (x1, y1), (x2, y2), (x3, y3), and (x4, y4) are the coordinates of the bounding box and text is the text inside the bounding box.
# 3. **entities**: This folder contains the ground truth information of the entities in the receipts. The file is a text file with the same name as the image file but with a .txt extension. The file contains json data with the following format:
#     ```json
#     {
#         "company": "COMPANY_NAME",
#         "date": "DATE",
#         "address": "ADDRESS",
#         "total": "TOTAL",
#     }
#     ```

# %% [markdown]
# ## Image Preprocesing: OpenCV

# %%
! pip install opencv-python matplotlib numpy
# Out:
# Requirement already satisfied: opencv-python in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (4.12.0.88)
# Requirement already satisfied: matplotlib in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (3.10.0)
# Requirement already satisfied: numpy in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# Let's take one image and play with it.

# %%
import os
one_image_path = os.path.join(path, 'SROIE2019', 'train', 'img', 'X51005453729.jpg')

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

def display_image(image, title="Image"):
    plt.figure(figsize=(7, 7))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
one_image = cv2.imread(one_image_path)
display_image(one_image, "Original Receipt Image")

# %% [markdown]
# ### Grayscale Conversion
#
# **Why?** Color information is usually not necessary for reading the text on a receipt. Converting the image to grayscale simplifies it from three color channels (Red, Green, Blue) to a single channel (intensity/brightness). This reduces computational complexity and is a required first step for many subsequent operations like thresholding.

# %%
# Convert the image to grayscale
def convert_to_grayscale(image):
  return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
grayscale_image = convert_to_grayscale(one_image)
display_image(grayscale_image, "Grayscale Image")

# %% [markdown]
# ### Noise (blur) Reduction
# **Why?** Scanned images or photos often contain "noise" (random variations in brightness or color). This can look like small specks or graininess, which can confuse OCR algorithms. Applying a slight blur helps to smooth out this noise. A **Gaussian blur** is a common choice as it effectively averages out pixel values with a weighted average, preserving edges better than a simple blur.

# %%
def reduce_noise(gray_image):
  return cv2.GaussianBlur(gray_image, (5, 5), 0)

# %%
blur_reduced_image = reduce_noise(grayscale_image)
display_image(blur_reduced_image, "Blur Reduced Image")

# %% [markdown]
# ### Binarization (Thresholding)
#
# **Why?** This is one of the most critical steps. Binarization converts the grayscale image into a pure black-and-white image. The goal is to make the text **black** and the background **white**. However, receipts often have uneven lighting or shadows, so a simple (global) threshold won't work well. We use **adaptive thresholding**, which calculates a different threshold for smaller regions of the image, making it robust to lighting changes.

# %% [markdown]
# `cv2.adaptiveThreshold()`:
#
#   * `cv2.ADAPTIVE_THRESH_GAUSSIAN_C`: Calculates the threshold for a pixel based on a weighted sum of neighborhood values.
#   * `cv2.THRESH_BINARY_INV`: Inverts the result. We want the text to be white pixels (value 255) and the background black (value 0) for the next step (skew correction), which often works by finding white pixel contours.
#   * `11`: The size of the neighborhood area (block size).
#   * `4`: A constant subtracted from the mean. It's a fine-tuning parameter.

# %%
def binarize_image(blur_reduced_image):
  return cv2.adaptiveThreshold(
    blur_reduced_image,
    255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY_INV, # Invert the colors (text becomes white)
    11, # Block size
    4  # Constant C
  )

# %%
binarized_image = binarize_image(blur_reduced_image)
display_image(binarized_image, "Binarized Image")

# %% [markdown]
# ### Skew Correction
#
# **Why?** Receipts are often scanned or photographed at a slight angle. This skew can significantly reduce the accuracy of OCR. We need to detect this angle and rotate the image to make the text perfectly horizontal.
#
# A common technique is to find the angle of the minimum-area bounding box that encloses all the text (the white pixels in our binarized image) and then rotate the original image by that angle.

# %%
# Complete working version with all dependencies
import os
import cv2
import time

# Set the path to your SROIE2019 dataset using local Kaggle cache
# This points to your local Kaggle dataset cache location
path = "/Users/ganeshkanagavel/.cache/kagglehub/datasets/urbikn/sroie-datasetv2/versions/4"

# Check if the dataset exists
dataset_path = os.path.join(path, 'SROIE2019', 'train', 'img')
if not os.path.exists(dataset_path):
    print(f"❌ Dataset not found at: {dataset_path}")
    print("Please ensure the SROIE2019 dataset is downloaded via Kaggle.")
    print("You can download it using: kaggle datasets download -d urbikn/sroie-datasetv2")
    print("Or check if the dataset is in your Kaggle cache at the expected location.")
else:
    print(f"✅ Dataset found at: {dataset_path}")
    # Count available images
    image_files = [f for f in os.listdir(dataset_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    print(f"Found {len(image_files)} images in the dataset")

    # Also check test dataset
    test_dataset_path = os.path.join(path, 'SROIE2019', 'test', 'img')
    if os.path.exists(test_dataset_path):
        test_image_files = [f for f in os.listdir(test_dataset_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        print(f"Found {len(test_image_files)} test images in the dataset")
# Out:
# ✅ Dataset found at: /Users/ganeshkanagavel/.cache/kagglehub/datasets/urbikn/sroie-datasetv2/versions/4/SROIE2019/train/img
# Found 626 images in the dataset
# Found 347 test images in the dataset

# %%
# Image processing functions (if not already defined)
def convert_to_grayscale(image):
    """Convert image to grayscale"""
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

def reduce_noise(image):
    """Reduce noise in the image"""
    return cv2.medianBlur(image, 5)

def binarize_image(image):
    """Convert image to binary (black and white)"""
    _, binary = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return binary

def process_one_image(image):
    """Complete image processing pipeline"""
    print("Starting image processing...")
    image = convert_to_grayscale(image)
    print("Converted image to grayscale..")
    image = reduce_noise(image)
    print("Reduced noise in the image..")
    image = binarize_image(image)
    print("Binarized the image..")
    print("Image processing completed!")
    return image

print("✅ Image processing functions defined")
# Out:
# ✅ Image processing functions defined

# %%
# Your corrected image processing code
import time
output_folder_path = "content/processed_images"
start_time = time.time()

# Create output directory
if os.makedirs(output_folder_path, exist_ok=True):
  print(f"Created folder: {output_folder_path}")

# Check if dataset exists before processing
dataset_path = os.path.join(path, 'SROIE2019', 'train', 'img')
if not os.path.exists(dataset_path):
    print(f"❌ Error: Dataset not found at {dataset_path}")
    print("Please ensure the SROIE2019 dataset is downloaded and placed correctly.")
else:
    print(f"✅ Processing images from: {dataset_path}")

    # Get list of images (limit to first 20 for testing)
    image_files = [f for f in os.listdir(dataset_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    images_to_process = image_files[:20]

    print(f"Processing {len(images_to_process)} images...")

    for i, image_name in enumerate(images_to_process, 1):
        print(f"\n[{i}/{len(images_to_process)}] Processing image: {image_name}")
        image_path = os.path.join(dataset_path, image_name)

        # Load and process image
        image = cv2.imread(image_path)
        if image is None:
            print(f"❌ Could not load image: {image_name}")
            continue

        processed_image = process_one_image(image)

        # Save processed image
        output_path = os.path.join(output_folder_path, image_name)
        success = cv2.imwrite(output_path, processed_image)

        if success:
            print(f"✅ Saved processed image to: {output_path}")
        else:
            print(f"❌ Failed to save image: {output_path}")
        print("-" * 50)

    print("\n🎉 Processing images completed!")
    print(f"Total time taken: {time.time() - start_time:.2f} seconds")
# Out:
# ✅ Processing images from: /Users/ganeshkanagavel/.cache/kagglehub/datasets/urbikn/sroie-datasetv2/versions/4/SROIE2019/train/img
# Processing 20 images...
#
# [1/20] Processing image: X51005442376.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51005442376.jpg
# --------------------------------------------------
#
# [2/20] Processing image: X51009453804.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51009453804.jpg
# --------------------------------------------------
#
# [3/20] Processing image: X51006401723.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51006401723.jpg
# --------------------------------------------------
#
# [4/20] Processing image: X51006913023.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51006913023.jpg
# --------------------------------------------------
#
# [5/20] Processing image: X51007846451.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51007846451.jpg
# --------------------------------------------------
#
# [6/20] Processing image: X51006311780.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51006311780.jpg
# --------------------------------------------------
#
# [7/20] Processing image: X51005719862.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51005719862.jpg
# --------------------------------------------------
#
# [8/20] Processing image: X51007339133.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51007339133.jpg
# --------------------------------------------------
#
# [9/20] Processing image: X51006008057.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51006008057.jpg
# --------------------------------------------------
#
# [10/20] Processing image: X51005719902.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51005719902.jpg
# --------------------------------------------------
#
# [11/20] Processing image: X51006557161.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51006557161.jpg
# --------------------------------------------------
#
# [12/20] Processing image: X51006857265.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51006857265.jpg
# --------------------------------------------------
#
# [13/20] Processing image: X51005757304.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51005757304.jpg
# --------------------------------------------------
#
# [14/20] Processing image: X51005447839.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51005447839.jpg
# --------------------------------------------------
#
# [15/20] Processing image: X51006332575.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51006332575.jpg
# --------------------------------------------------
#
# [16/20] Processing image: X00016469612.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X00016469612.jpg
# --------------------------------------------------
#
# [17/20] Processing image: X51006389888.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51006389888.jpg
# --------------------------------------------------
#
# [18/20] Processing image: X51006328920.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51006328920.jpg
# --------------------------------------------------
#
# [19/20] Processing image: X51006620190.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51006620190.jpg
# --------------------------------------------------
#
# [20/20] Processing image: X51006620191.jpg
# Starting image processing...
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Image processing completed!
# ✅ Saved processed image to: content/processed_images/X51006620191.jpg
# --------------------------------------------------
#
# 🎉 Processing images completed!
# Total time taken: 0.51 seconds

# %%
# Fixed OCR testing cell with correct local paths
from PIL import Image
import pytesseract
import os

# Check if processed images exist
processed_images_path = "content/processed_images"
if not os.path.exists(processed_images_path):
    print(f"❌ Processed images folder not found: {processed_images_path}")
    print("Please run the image processing code first to generate processed images.")
else:
    # List available processed images
    processed_files = [f for f in os.listdir(processed_images_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    print(f"✅ Found {len(processed_files)} processed images")

    if processed_files:
        # Test OCR on the first available image
        test_image = processed_files[0]
        image_path = os.path.join(processed_images_path, test_image)
        print(f"Testing OCR on: {test_image}")

        try:
            # Extract text using Tesseract
            extracted_text = pytesseract.image_to_string(Image.open(image_path))
            print("=" * 50)
            print("EXTRACTED TEXT:")
            print("=" * 50)
            print(extracted_text)
            print("=" * 50)
        except Exception as e:
            print(f"❌ Error during OCR: {e}")
    else:
        print("No processed images found in the folder.")

# %%
# Installation and setup cell for OCR functionality
import subprocess
import sys

def install_package(package):
    """Install a package using pip"""
    try:
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])
        print(f"✅ Successfully installed {package}")
        return True
    except subprocess.CalledProcessError as e:
        print(f"❌ Failed to install {package}: {e}")
        return False

# Check if pytesseract is installed
try:
    import pytesseract
    print("✅ pytesseract is already installed")
except ImportError:
    print("📦 Installing pytesseract...")
    install_package("pytesseract")

# Check if PIL is installed
try:
    from PIL import Image
    print("✅ PIL (Pillow) is already installed")
except ImportError:
    print("📦 Installing Pillow...")
    install_package("Pillow")

# Test Tesseract installation
try:
    import pytesseract
    # Test if tesseract command is available
    pytesseract.get_tesseract_version()
    print("✅ Tesseract OCR engine is working")
except Exception as e:
    print(f"❌ Tesseract OCR engine issue: {e}")
    print("💡 If you're on macOS, run: brew install tesseract")
    print("💡 If you're on Ubuntu/Debian, run: sudo apt-get install tesseract-ocr")
    print("💡 If you're on Windows, download from: https://github.com/UB-Mannheim/tesseract/wiki")

print("\n🎯 Ready for OCR processing!")

# %%
def deskew_image(image):
    """
    Corrects the skew of an image by finding the minimum area rectangle
    of the text block and rotating accordingly.
    """
    # Find all non-zero (white) pixels
    coords = cv2.findNonZero(image)

    # Get the minimum area bounding rectangle
    # It returns (center(x,y), (width, height), angle of rotation)
    rect = cv2.minAreaRect(coords)
    angle = rect[-1] - 90

    # The `cv2.minAreaRect` angle has a specific range.
    # We need to adjust it for our rotation.
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = angle

    # Get the rotation matrix and rotate the image
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h),
                             flags=cv2.INTER_CUBIC,
                             borderMode=cv2.BORDER_REPLICATE)
    print(f"Detected skew angle: {angle:.2f} degrees")

    # Now, rotate the original grayscale image by the same angle
    (h, w) = rotated.shape
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    deskewed_gray = cv2.warpAffine(rotated, M, (w, h),
                                  flags=cv2.INTER_CUBIC,
                                  borderMode=cv2.BORDER_REPLICATE)

    return deskewed_gray

# %%
deskewed_image = deskew_image(binarized_image)
# Out:
# Detected skew angle: -2.91 degrees

# %%
display_image(deskewed_image, "Deskewed Image")

# %% [markdown]
# Let's run the above code for all images

# %%
def process_one_image(image):
  image = convert_to_grayscale(image)
  print("Converted image to grayscale..")
  image = reduce_noise(image)
  print("Reduced noise in the image..")
  image = binarize_image(image)
  print("Binarized the image..")
  image = deskew_image(image)
  print("Corrected image orientation..")
  return image

# %%
from gettext import install

# %%
import time
output_folder_path = "content/processed_images"
start_time = time.time()

if os.makedirs(output_folder_path, exist_ok=True):
  print(f"Created folder: {output_folder_path}")


for image_name in os.listdir(os.path.join(path, 'SROIE2019', 'train', 'img'))[:20]:
  print(f"Processing image: {image_name}")
  image_path = os.path.join(path, 'SROIE2019', 'train', 'img', image_name)
  image = cv2.imread(image_path)
  processed_image = process_one_image(image)
  # save image
  output_path = os.path.join(output_folder_path, image_name)
  cv2.imwrite(output_path, processed_image)
  print(f"Saved processed image to: {output_path}")
  print("-"*50)

print("Processing images is completed.")
print(f"Total time taken: {time.time() - start_time} seconds")
# Out:
# Processing image: X51005442376.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: 0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51005442376.jpg
# --------------------------------------------------
# Processing image: X51009453804.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: 0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51009453804.jpg
# --------------------------------------------------
# Processing image: X51006401723.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: 0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51006401723.jpg
# --------------------------------------------------
# Processing image: X51006913023.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: 0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51006913023.jpg
# --------------------------------------------------
# Processing image: X51007846451.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: 0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51007846451.jpg
# --------------------------------------------------
# Processing image: X51006311780.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: -0.10 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51006311780.jpg
# --------------------------------------------------
# Processing image: X51005719862.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: -0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51005719862.jpg
# --------------------------------------------------
# Processing image: X51007339133.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: 0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51007339133.jpg
# --------------------------------------------------
# Processing image: X51006008057.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: 0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51006008057.jpg
# --------------------------------------------------
# Processing image: X51005719902.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: 0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51005719902.jpg
# --------------------------------------------------
# Processing image: X51006557161.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: -0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51006557161.jpg
# --------------------------------------------------
# Processing image: X51006857265.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: -0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51006857265.jpg
# --------------------------------------------------
# Processing image: X51005757304.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: 0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51005757304.jpg
# --------------------------------------------------
# Processing image: X51005447839.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: -0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51005447839.jpg
# --------------------------------------------------
# Processing image: X51006332575.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: 0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51006332575.jpg
# --------------------------------------------------
# Processing image: X00016469612.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: 0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X00016469612.jpg
# --------------------------------------------------
# Processing image: X51006389888.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: -0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51006389888.jpg
# --------------------------------------------------
# Processing image: X51006328920.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: -0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51006328920.jpg
# --------------------------------------------------
# Processing image: X51006620190.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: 0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51006620190.jpg
# --------------------------------------------------
# Processing image: X51006620191.jpg
# Converted image to grayscale..
# Reduced noise in the image..
# Binarized the image..
# Detected skew angle: 0.00 degrees
# Corrected image orientation..
# Saved processed image to: content/processed_images/X51006620191.jpg
# --------------------------------------------------
# Processing images is completed.
# Total time taken: 8.30935001373291 seconds

# %% [markdown]
# ## Text Extraction: Tesseract

# %% [markdown]
# Tesseract OCR is a powerful and widely-used open-source optical character recognition (OCR) engine. In simple terms, it's a software that can "read" text from images and convert it into machine-readable text. This means you can take a picture of a document, a sign, or any other object containing text, and Tesseract can extract that text so you can edit, search, or analyze it.
#
# ### A Brief History and Development
#
# Originally developed by Hewlett-Packard in the 1980s, Tesseract was later open-sourced in 2005 and has been sponsored by Google since 2006. This has led to significant improvements and made it one of the most accurate and versatile free OCR engines available. The latest versions of Tesseract utilize long short-term memory (LSTM), a type of recurrent neural network (RNN), which has greatly enhanced its ability to recognize text with high accuracy.

# %% [markdown]
# ### Core Functionalities and Capabilities
#
# Tesseract boasts a rich set of features that make it a flexible tool for various applications:
#
#   * **Extensive Language Support:** Tesseract can recognize over 100 languages, making it a truly global OCR solution. It also supports multiple scripts and can even be trained to recognize new languages.
#   * **Multiple Output Formats:** It can output the recognized text in various formats, including plain text, HTML, PDF, and TSV (tab-separated values). This allows for easy integration with other software and workflows.
#   * **Page Segmentation Modes:** Tesseract offers different page segmentation modes, which help in correctly identifying the layout of a document, including columns, paragraphs, and blocks of text.
#   * **Character Recognition and Confidence:** Not only does it recognize characters, but it can also provide a confidence score for each recognized character, word, or line. This is useful for assessing the accuracy of the OCR process.
#   * **Command-Line and API Access:** Tesseract can be used as a command-line tool for quick and simple OCR tasks. For more complex integrations, it provides an API that allows developers to incorporate its OCR capabilities into their own applications. Popular wrappers like Pytesseract make it easy to use Tesseract with programming languages like Python.

# %% [markdown]
# ### Installation
# `pip install pytesseract pillow`

# %% [markdown]
# ### How to Use Tesseract
#
# For developers, integrating Tesseract into an application is straightforward using its API. Here is a simple example using the `pytesseract` wrapper in Python:
#
# ```python
#
# from PIL import Image
# import pytesseract
#
#
# text = pytesseract.image_to_string(Image.open(filename))
#
# print(text)
# ```

# %% [markdown]
# ### Common Use Cases and Applications
#
# The ability to extract text from images opens up a vast range of applications across various industries:
#
#   * **Document Digitization:** Converting scanned documents, books, and historical archives into searchable digital text.
#   * **Data Entry Automation:** Automating the process of entering data from invoices, receipts, and forms.
#   * **Accessibility:** Assisting visually impaired individuals by converting printed text into speech.
#   * **License Plate Recognition:** In law enforcement and traffic management systems.
#   * **Social Media Monitoring:** Analyzing text within images shared on social media platforms.
#   * **Translation:** Extracting text from an image and then using a translation service to translate it.
#
# While Tesseract is a powerful tool, the accuracy of its output heavily depends on the quality of the input image. For best results, images should be clear, well-lit, and have a high resolution. Pre-processing steps like resizing, noise reduction, and converting to grayscale can significantly improve OCR accuracy.

# %%
! pip install pytesseract pillow
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (11.3.0)
# Requirement already satisfied: packaging>=21.3 in /Users/ganeshkanagavel/Library/CloudStorage/GoogleDrive-kganesk@gmail.com/My Drive/Ganesh/Learning/AIProjects/Project1-EDA/agentic_AI_py312/lib/python3.12/site-packages (from pytesseract) (25.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13

# %%
from PIL import Image
import pytesseract

pytesseract.image_to_string(Image.open('content/processed_images/X00016469612.jpg'))
# Out:
# 'tan woon yann\n\nBOOK TA & TAMAN DATA! SOM ONE\n\nwe a\ntee\nCASH BILL\n‘\nRousd 4 Total /HM) vu\n/:\nast 1 . . were Ta\n'

# %%
from PIL import Image
import pytesseract
import time

input_folder_path = "content/processed_images"
output_folder_path = "content/tesseract_output"
start_time = time.time()

if os.makedirs(output_folder_path, exist_ok=True):
  print(f"Created folder: {output_folder_path}")

total_images = sum(1 for entry in os.scandir(input_folder_path))
print(f"Total images in folder: {total_images}")

for i, image_name in enumerate(os.listdir(input_folder_path)[:20], 1):
  print(f"Processing image {i}/{total_images}: {image_name}")
  image_path = os.path.join(input_folder_path, image_name)
  print("Extracting text from image..")
  text = pytesseract.image_to_string(Image.open(image_path))
  output_path = os.path.join(output_folder_path, image_name.replace(".jpg", ".txt"))
  with open(output_path, "w") as f:
    f.write(text)

  print(f"Saved extracted text to {output_path}")
  print("-"*50)

print("Text Extraction Completed.")
print(f"Total time taken: {time.time() - start_time} seconds")
# Out:
# Total images in folder: 20
# Processing image 1/20: X51005442376.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51005442376.txt
# --------------------------------------------------
# Processing image 2/20: X51009453804.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51009453804.txt
# --------------------------------------------------
# Processing image 3/20: X51006401723.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51006401723.txt
# --------------------------------------------------
# Processing image 4/20: X51006913023.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51006913023.txt
# --------------------------------------------------
# Processing image 5/20: X51007846451.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51007846451.txt
# --------------------------------------------------
# Processing image 6/20: X51006311780.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51006311780.txt
# --------------------------------------------------
# Processing image 7/20: X51005719862.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51005719862.txt
# --------------------------------------------------
# Processing image 8/20: X51007339133.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51007339133.txt
# --------------------------------------------------
# Processing image 9/20: X51006008057.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51006008057.txt
# --------------------------------------------------
# Processing image 10/20: X51005719902.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51005719902.txt
# --------------------------------------------------
# Processing image 11/20: X51006557161.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51006557161.txt
# --------------------------------------------------
# Processing image 12/20: X51006857265.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51006857265.txt
# --------------------------------------------------
# Processing image 13/20: X51005757304.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51005757304.txt
# --------------------------------------------------
# Processing image 14/20: X51005447839.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51005447839.txt
# --------------------------------------------------
# Processing image 15/20: X51006332575.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51006332575.txt
# --------------------------------------------------
# Processing image 16/20: X00016469612.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X00016469612.txt
# --------------------------------------------------
# Processing image 17/20: X51006389888.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51006389888.txt
# --------------------------------------------------
# Processing image 18/20: X51006328920.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51006328920.txt
# --------------------------------------------------
# Processing image 19/20: X51006620190.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51006620190.txt
# --------------------------------------------------
# Processing image 20/20: X51006620191.jpg
# Extracting text from image..
# Saved extracted text to content/tesseract_output/X51006620191.txt
# --------------------------------------------------
# Text Extraction Completed.
# Total time taken: 7.336665153503418 seconds

# %% [markdown]
# ## Information Extraction

# %%
prompt = """
Extract the information from the given image.
Information to be extracted: company, date, address, total.
The image has been converted to grayscale, noise reduced, binarized, and deskewed using opencv.
Always give your response in the following format:
{
    "company": "COMPANY_NAME",
    "date": "DATE",
    "address": "ADDRESS",
    "total": "TOTAL",
}
Also, the text has been extracted from the image using tesseract.
Use the extracted text as support for extracting information.
If you believe the extraction is incorrect somewhere, you may correct it yourself and provide corrected information.
Respond with the extracted information only in the specified format.
Here is the text:


"""

# %% [markdown]
# Can we improve the prompt using the [Unified Framework For An Effective Prompt](https://www.geeksforgeeks.org/data-science/a-unified-framework-for-an-effective-prompt/)?

# %%
from google import genai
#from google.colab import userdata # colab only code
from PIL import Image
import json
import time

# %%
genai_client = genai.Client(api_key='AIzaSyBifvdQBqpVM6RvYfIvzVD26fDmVAFdgjI')

# %%
image_folder_path = "content/processed_images"
text_folder_path = "content/tesseract_output"
output_folder_path = "content/json_output"

start_time = time.time()

if os.makedirs(output_folder_path, exist_ok=True):
  print(f"Created folder: {output_folder_path}")

total_images = sum(1 for entry in os.scandir(image_folder_path))
print(f"Total images in folder: {total_images}")

for i, image_name in enumerate(os.listdir(input_folder_path)[:20], 1):
  print(f"Processing image {i}/{total_images}: {image_name}")
  image_path = os.path.join(input_folder_path, image_name)
  print(f"Loading image: {image_path}")
  with open(image_path, "rb") as f:
    image = Image.open(image_path)


  text_path = os.path.join(text_folder_path, image_name.replace(".jpg", ".txt"))
  print(f"Loading extracted text: {text_path}")
  with open(text_path, "r") as f:
    text = f.read()

  print("Extracting information from image and text..")

  prompt = prompt + text



  contents = [
        image,
        {
            "text": prompt
        }
    ]
  response = genai_client.models.generate_content(model='gemini-1.5-flash', contents=contents)

  # Access the usage_metadata attribute
  usage_metadata = response.usage_metadata

  # Print the different token counts
  print(f"Input Token Count: {usage_metadata.prompt_token_count}")
  print(f"Thoughts Token Count: {response.usage_metadata.thoughts_token_count}")
  print(f"Output Token Count: {usage_metadata.candidates_token_count}")
  print(f"Total Token Count: {usage_metadata.total_token_count}")

  extracted_information = json.loads(response.text.replace('```json', '').replace('```', ''))
  output_path = os.path.join(output_folder_path, image_name.replace(".jpg", ".json"))
  with open(output_path, "w") as f:
    json.dump(extracted_information, f, indent=4)

  print(f"Saved extracted information to {output_path}")
  print("-"*50)
  time.sleep(60)

print("Information Extraction Completed.")
print(f"Total time taken: {time.time() - start_time} seconds")
# Out:
# Total images in folder: 20
# Processing image 1/20: X51005442376.jpg
# Loading image: content/processed_images/X51005442376.jpg
# Loading extracted text: content/tesseract_output/X51005442376.txt
# Extracting information from image and text..
# Input Token Count: 503
# Thoughts Token Count: None
# Output Token Count: 35
# Total Token Count: 538
# Saved extracted information to content/json_output/X51005442376.json
# --------------------------------------------------
# Processing image 2/20: X51009453804.jpg
# Loading image: content/processed_images/X51009453804.jpg
# Loading extracted text: content/tesseract_output/X51009453804.txt
# Extracting information from image and text..
# Input Token Count: 726
# Thoughts Token Count: None
# Output Token Count: 97
# Total Token Count: 823
# Saved extracted information to content/json_output/X51009453804.json
# --------------------------------------------------
# Processing image 3/20: X51006401723.jpg
# Loading image: content/processed_images/X51006401723.jpg
# Loading extracted text: content/tesseract_output/X51006401723.txt
# Extracting information from image and text..
# Input Token Count: 1075
# Thoughts Token Count: None
# Output Token Count: 101
# Total Token Count: 1176
# Saved extracted information to content/json_output/X51006401723.json
# --------------------------------------------------
# Processing image 4/20: X51006913023.jpg
# Loading image: content/processed_images/X51006913023.jpg
# Loading extracted text: content/tesseract_output/X51006913023.txt
# Extracting information from image and text..
# Input Token Count: 1358
# Thoughts Token Count: None
# Output Token Count: 93
# Total Token Count: 1451
# Saved extracted information to content/json_output/X51006913023.json
# --------------------------------------------------
# Processing image 5/20: X51007846451.jpg
# Loading image: content/processed_images/X51007846451.jpg
# Loading extracted text: content/tesseract_output/X51007846451.txt
# Extracting information from image and text..
# Input Token Count: 1682
# Thoughts Token Count: None
# Output Token Count: 100
# Total Token Count: 1782
# Saved extracted information to content/json_output/X51007846451.json
# --------------------------------------------------
# Processing image 6/20: X51006311780.jpg
# Loading image: content/processed_images/X51006311780.jpg
# Loading extracted text: content/tesseract_output/X51006311780.txt
# Extracting information from image and text..
# Input Token Count: 1974
# Thoughts Token Count: None
# Output Token Count: 97
# Total Token Count: 2071
# Saved extracted information to content/json_output/X51006311780.json
# --------------------------------------------------
# Processing image 7/20: X51005719862.jpg
# Loading image: content/processed_images/X51005719862.jpg
# Loading extracted text: content/tesseract_output/X51005719862.txt
# Extracting information from image and text..
# Input Token Count: 2194
# Thoughts Token Count: None
# Output Token Count: 100
# Total Token Count: 2294
# Saved extracted information to content/json_output/X51005719862.json
# --------------------------------------------------
# Processing image 8/20: X51007339133.jpg
# Loading image: content/processed_images/X51007339133.jpg
# Loading extracted text: content/tesseract_output/X51007339133.txt
# Extracting information from image and text..
# Input Token Count: 2315
# Thoughts Token Count: None
# Output Token Count: 83
# Total Token Count: 2398
# Saved extracted information to content/json_output/X51007339133.json
# --------------------------------------------------
# Processing image 9/20: X51006008057.jpg
# Loading image: content/processed_images/X51006008057.jpg
# Loading extracted text: content/tesseract_output/X51006008057.txt
# Extracting information from image and text..
# Input Token Count: 2771
# Thoughts Token Count: None
# Output Token Count: 87
# Total Token Count: 2858
# Saved extracted information to content/json_output/X51006008057.json
# --------------------------------------------------
# Processing image 10/20: X51005719902.jpg
# Loading image: content/processed_images/X51005719902.jpg
# Loading extracted text: content/tesseract_output/X51005719902.txt
# Extracting information from image and text..
# Input Token Count: 3087
# Thoughts Token Count: None
# Output Token Count: 103
# Total Token Count: 3190
# Saved extracted information to content/json_output/X51005719902.json
# --------------------------------------------------
# Processing image 11/20: X51006557161.jpg
# Loading image: content/processed_images/X51006557161.jpg
# Loading extracted text: content/tesseract_output/X51006557161.txt
# Extracting information from image and text..
# Input Token Count: 3522
# Thoughts Token Count: None
# Output Token Count: 119
# Total Token Count: 3641
# Saved extracted information to content/json_output/X51006557161.json
# --------------------------------------------------
# Processing image 12/20: X51006857265.jpg
# Loading image: content/processed_images/X51006857265.jpg
# Loading extracted text: content/tesseract_output/X51006857265.txt
# Extracting information from image and text..
# Input Token Count: 3856
# Thoughts Token Count: None
# Output Token Count: 93
# Total Token Count: 3949
# Saved extracted information to content/json_output/X51006857265.json
# --------------------------------------------------
# Processing image 13/20: X51005757304.jpg
# Loading image: content/processed_images/X51005757304.jpg
# Loading extracted text: content/tesseract_output/X51005757304.txt
# Extracting information from image and text..
# Input Token Count: 4087
# Thoughts Token Count: None
# Output Token Count: 99
# Total Token Count: 4186
# Saved extracted information to content/json_output/X51005757304.json
# --------------------------------------------------
# Processing image 14/20: X51005447839.jpg
# Loading image: content/processed_images/X51005447839.jpg
# Loading extracted text: content/tesseract_output/X51005447839.txt
# Extracting information from image and text..
# Input Token Count: 4377
# Thoughts Token Count: None
# Output Token Count: 94
# Total Token Count: 4471
# Saved extracted information to content/json_output/X51005447839.json
# --------------------------------------------------
# Processing image 15/20: X51006332575.jpg
# Loading image: content/processed_images/X51006332575.jpg
# Loading extracted text: content/tesseract_output/X51006332575.txt
# Extracting information from image and text..
# Input Token Count: 4743
# Thoughts Token Count: None
# Output Token Count: 104
# Total Token Count: 4847
# Saved extracted information to content/json_output/X51006332575.json
# --------------------------------------------------
# Processing image 16/20: X00016469612.jpg
# Loading image: content/processed_images/X00016469612.jpg
# Loading extracted text: content/tesseract_output/X00016469612.txt
# Extracting information from image and text..
# Input Token Count: 4789
# Thoughts Token Count: None
# Output Token Count: 54
# Total Token Count: 4843
# Saved extracted information to content/json_output/X00016469612.json
# --------------------------------------------------
# Processing image 17/20: X51006389888.jpg
# Loading image: content/processed_images/X51006389888.jpg
# Loading extracted text: content/tesseract_output/X51006389888.txt
# Extracting information from image and text..
# Input Token Count: 5198
# Thoughts Token Count: None
# Output Token Count: 110
# Total Token Count: 5308
# Saved extracted information to content/json_output/X51006389888.json
# --------------------------------------------------
# Processing image 18/20: X51006328920.jpg
# Loading image: content/processed_images/X51006328920.jpg
# Loading extracted text: content/tesseract_output/X51006328920.txt
# Extracting information from image and text..
# Input Token Count: 5457
# Thoughts Token Count: None
# Output Token Count: 84
# Total Token Count: 5541
# Saved extracted information to content/json_output/X51006328920.json
# --------------------------------------------------
# Processing image 19/20: X51006620190.jpg
# Loading image: content/processed_images/X51006620190.jpg
# Loading extracted text: content/tesseract_output/X51006620190.txt
# Extracting information from image and text..
# Input Token Count: 5781
# Thoughts Token Count: None
# Output Token Count: 116
# Total Token Count: 5897
# Saved extracted information to content/json_output/X51006620190.json
# --------------------------------------------------
# Processing image 20/20: X51006620191.jpg
# Loading image: content/processed_images/X51006620191.jpg
# Loading extracted text: content/tesseract_output/X51006620191.txt
# Extracting information from image and text..
# Input Token Count: 6057
# Thoughts Token Count: None
# Output Token Count: 86
# Total Token Count: 6143
# Saved extracted information to content/json_output/X51006620191.json
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 56
#      54   print(f"Saved extracted information to {output_path}")
#      55   print("-"*50)
# ---> 56   time.sleep(60)
#      58 print("Information Extraction Completed.")
#      59 print(f"Total time taken: {time.time() - start_time} seconds")
#
# KeyboardInterrupt:

# %% [markdown]
# # Can you play with a Resume Dataset?
#
# https://www.kaggle.com/datasets/snehaanbhawal/resume-dataset
